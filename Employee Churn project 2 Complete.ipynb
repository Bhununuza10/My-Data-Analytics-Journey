# %%
import numpy as np
import pandas as pd


data = pd.read_csv(r"C:\Users\busani\Desktop\Data Science\Python vidz\Data1\HR_comma_sep.csv")

# %%
data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Data Preprocessing:

# %%
# Data Preprocessing:

#identifying missing values

data.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
# Checkikng of duplicate values:

data[data.duplicated()]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 396                  0.46             0.57               2
# 866                  0.41             0.46               2
# 1317                 0.37             0.51               2
# 1368                 0.41             0.52               2
# 1461                 0.42             0.53               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 396                     139                   3              0     1
# 866                     128                   3              0     1
# ...

# %%
# Removing duplicate values(rows) in dataset( keeping the first ):


data = data.drop_duplicates()

# %%
data.shape
# Out:
# (11991, 10)

# %% [markdown]
# ### Checking for relationships within the dataset(CORRELATION)

# %%
# Checking for relationships within the dataset(CORRELATION)

# * Positive correlation means relationship between variables is moving in the same direction
# * Negative correlation means relationship between variables is moving in opposite direction
# * Zero correlation means there is no relationship between said variables(columns)
data.corr()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.095186       -0.133246
# last_evaluation                  0.095186         1.000000        0.270256
# number_project                  -0.133246         0.270256        1.000000
# average_montly_hours            -0.006252         0.264678        0.331516
# time_spend_company              -0.152915         0.096829        0.188837
# Work_accident                    0.039940        -0.005695       -0.005612
# left                            -0.350558         0.013520        0.030928
# promotion_last_5years            0.019789        -0.007206       -0.000544
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.006252           -0.152915
# last_evaluation                    0.264678            0.096829
# number_project                     0.331516            0.188837
# ...

# %%
# Visualisation of correlation between variables(columns)

lft = ["Department","number_project","time_spend_company","Work_accident","promotion_last_5years","salary"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig = plt.subplots(figsize=(18,15))

for p,q in enumerate(lft):
    plt.subplot(4,2,p+1)
    plt.subplots_adjust(hspace=1.0)
    sns.countplot(x=q,data=data, hue = "left")
    plt.xticks(rotation=90)

# %% [markdown]
# #### Analysis of visuals above:
# ######
#      * Sales department experiences the most number of employees leaving the organization
#      * Employees with 3 -4 projects are the ones that leave the organization the most
#      * Most employees leave the company after spending 2- 4 years in the company, 3years being the most
#      * Employees with 0 promotions in the last 5 years tend to be ones most likely to leave the company
#      * high level of mmployees with low and medium salaries leaving the organization

# %% [markdown]
# #### Siyabonga M. Gamedze
